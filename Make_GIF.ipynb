# %%
import imageio
import os
import glob

# %%
L = glob.glob('/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_*.png')
L
# Out:
# ['/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h650.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h442.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h718.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h021.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h052.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h397.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h497.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h219.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h686.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h443.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h102.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h245.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h057.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h355.png',
#  '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h047.png',
# ...

# %%
def make_gif(path_to_imgs,file_list, img_format, fps):
    imgs, img_fnames = [], []
    # for fname in os.listdir(path_to_imgs):
    #     if fname.endswith('.'+img_format):
    #         img_fnames.append(fname)     
    img_fnames = file_list.sort()
    print(file_list)
    #sorted_files = sorted(img_fnames, key=lambda y: int(y.split('_')[1]))
    for i in range(len(file_list)):       
        f_path = os.path.join(path_to_imgs, file_list[i])
        imgs.append(imageio.imread(f_path))
    imageio.mimsave(os.path.join(path_to_imgs, '/global/homes/f/fzahura/Plots/ARW_Plots/2000-11.gif'), imgs, 'GIF', fps=fps)    



make_gif('', L,'png', 500) # an example
# Out:
# ['/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h000.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h001.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h002.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h003.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h004.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h005.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h006.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h007.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h008.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h009.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h010.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h011.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h012.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h013.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h014.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h015.png', '/global/homes/f/fzahura/Plots/NLDAS_
# ...

# %%
print(L.sort())

# %%
L.sort()

# %%
# def make_gif(path_to_imgs,file_list, img_format, fps):
imgs, img_fnames = [], []
    # for fname in os.listdir(path_to_imgs):
    #     if fname.endswith('.'+img_format):
    #         img_fnames.append(fname)     
img_fnames = L.sort()
print(L)
    #sorted_files = sorted(img_fnames, key=lambda y: int(y.split('_')[1]))
for i in range(len(file_list)):       
    f_path = os.path.join(path_to_imgs, file_list[i])
    imgs.append(imageio.imread(f_path))
imageio.mimsave(os.path.join(path_to_imgs, '/global/homes/f/fzahura/Plots/ARW_Plots/2000-11.gif'), imgs, 'GIF', fps=fps)
# Out:
# ['/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h000.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h001.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h002.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h003.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h004.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h005.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h006.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h007.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h008.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h009.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h010.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h011.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h012.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h013.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h014.png', '/global/homes/f/fzahura/Plots/NLDAS_ARW/2000-11_h015.png', '/global/homes/f/fzahura/Plots/NLDAS_
# ...
